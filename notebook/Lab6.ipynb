# %% [markdown]
# Remove the default sample_data folder from the /content directory.

# %%
# %%bash
# rm -r sample_data

# %% [markdown]
# Create a .gitignore file that tells Git to ignore the hidden .config

# %%
# %%bash
# cat > .gitignore
# .*
# .gitignore

# %%
# %%bash
# git config --global user.email "sandu.grecu88@gmail.com"
# git config --global user.name "sandu grecu"

# %% [markdown]
# Convert /content into a Git repository with git init.

# %%
# %%bash
# git init

# %%
# %%bash
# ls -a

# %% [markdown]
# Creating the three subdirectories

# %%
# %%bash
# mkdir summarydata
# mkdir notebook
# mkdir figure

# %% [markdown]
# Creating the README file

# %%
# %%bash
# cat > README.txt
# This repository contains 3 folders:
# summarydata - contains the data files used in lab 6
# notebook - contains all the IPython Notebook from lab 1-6
# figure - contains all figures created in lab 6
#
# Each folder also has a README file to help you understand what it contains.

# %% [markdown]
# Changing directory into summarydata, downloading the files, and creating the README file

# %%
# %%bash
# cd summarydata
# wget -nv -O titanic.csv 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
#
# cat > README.txt
# This subdirectory contains the titanic.csv file which has the data we used in lab 6.

# %% [markdown]
# Changing directory into notebook, downloading the files, and creating the README file

# %%
# %%bash
# cd notebook
# wget -nv -O Lab1.ipynb "https://drive.google.com/uc?export=download&id=1_gHraRsTA70i0x-zDjnqrvkxlpWKKe41"
# wget -nv -O Lab2.ipynb "https://drive.google.com/uc?export=download&id=1ybh-VLpDkCsrgOt-qY5B2eH8i0zX53k-"
# wget -nv -O Lab3.ipynb "https://drive.google.com/uc?export=download&id=13vS_F92Gj3Sq24SGbUTOuu7MJwnH7wVl"
# wget -nv -O Lab4.ipynb "https://drive.google.com/uc?export=download&id=1aOtvN7UVJf9JA-a8iOW7Z1B6OygCZcHP"
# wget -nv -O Lab5.ipynb "https://drive.google.com/uc?export=download&id=1VfUJADfZ3hXuC6bSOmljH6YPdupfcJkL"
# wget -nv -O Lab6.ipynb "https://drive.google.com/uc?export=download&id=1xOJ7kF8097Tj7yJOTBLYW_R6YTsQciUW"
#
# cat > README.txt
# This subdirectory contains all the ipynb files of lab 1-6.

# %% [markdown]
# Changing directory into figure, downloading the files, and creating the README file

# %%
# %%bash
# cd figure
# wget -nv -O Figure1.png "https://drive.google.com/uc?export=download&id=1S2C_jPjBGpP3bs-aeTlVl-JDc1BIDj1u"
# wget -nv -O Figure2.png "https://drive.google.com/uc?export=download&id=1VBdJO4j-ohHx84CuZtOjfRTrYsBsF41h"
# wget -nv -O Figure3.png "https://drive.google.com/uc?export=download&id=1tsB5YHeAWixdBte3Xbxh0SfxmzJ1A2sL"
# wget -nv -O Figure4.png "https://drive.google.com/uc?export=download&id=1WOrnEK9QzNGB866qQ7-88nOz33UxK1po"
# wget -nv -O Figure5.png "https://drive.google.com/uc?export=download&id=1fgvp3Jm936VJbv2kNLNkO3F1ynASGaof"
#
# cat > README.txt
# This subdirectory contains the figures that we created during lab 6.

# %% [markdown]
# Creating a set of public & private SSH keys to access practiceRepository from your Colab notebook

# %%
# %%bash
# ssh-keygen -t ed25519 -C '[sandu.grecu88@gmail.com]' -f ~/.ssh/id_ed25519 -P ''
# cat > ~/.ssh/config
# Host *
#   AddKeysToAgent yes
#   IdentityFile ~/.ssh/id_ed25519

# %%
# %%bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519

# %%
# %%bash
# cat ~/.ssh/id_ed25519.pub

# %% [markdown]
# Stage, commit, and push your Git repository to GitHub
